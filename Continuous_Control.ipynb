# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.30 which is incompatible.
# jupyter-console 6.4.3 has requirement jupyter-client>=7.0.0, but you'll have jupyter-client 5.2.4 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import random
import copy
from collections import deque, namedtuple

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Models
def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(33, 128)
        self.fc2 = nn.Linear(132, 128)
        self.fc3 = nn.Linear(128, 1)
        self.bn1 = nn.BatchNorm1d(128) # ADDED
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, states, actions):
        x = self.bn1(F.relu(self.fc1(states.to(device))))
        actions = torch.tensor(actions, dtype = torch.float)
        x = torch.cat((x, actions.to(device)), -1)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
class Actor(nn.Module):
    def __init__(self):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(33, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 4)
        self.bn1 = nn.BatchNorm1d(128) # ADDED
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, states):
        x = torch.tensor(states, dtype = torch.float).to(device)
        if x.dim() == 1: x = torch.unsqueeze(x,0) # ADDED
        x = self.bn1(F.relu(self.fc1(x)))
        x = F.relu(self.fc2(x))
        x = F.tanh(self.fc3(x))
        return x

# %%
class OUNoise:
    def __init__(self, size, mu=0., theta=0.15, sigma=0.1):
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.reset()

    def reset(self):
        self.state = copy.copy(self.mu)

    def sample(self):
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.random.randn(len(x)) # ADDED
        self.state = x + dx
        return self.state

# %%
# Agent
class Agent(nn.Module):
    def __init__(self, buffer_size, batch_size):
        super(Agent, self).__init__()
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "done", "next_state"])
        self.memory = deque(maxlen=self.buffer_size)
        self.dqn = Critic().to(device)
        self.dqn_target = Critic().to(device)
        for target_param, local_param in zip(self.dqn_target.parameters(), self.dqn.parameters()):
            target_param.data.copy_(local_param)
        self.policy = Actor().to(device)
        self.policy_target = Actor().to(device)
        for target_param, local_param in zip(self.policy_target.parameters(), self.policy.parameters()):
            target_param.data.copy_(local_param)
        self.optimizer_dqn = optim.Adam(self.dqn.parameters(), lr = 2e-4, weight_decay = 0)
        self.optimizer_policy = optim.Adam(self.policy.parameters(), lr = 2e-4)
        self.t_step = 0
        self.noise = OUNoise(4)
    
    def act(self, state, add_noise=True):
        state = torch.from_numpy(state).float().to(device)
        self.policy.eval()
        with torch.no_grad():
            action = self.policy(state).cpu().data.numpy()
        self.policy.train()
        action += self.noise.sample()
        return np.clip(action, -1, 1)
    
    def step(self, state, action, reward, done, next_state):
        e = self.experience(state, action, reward, done, next_state)
        self.memory.append(e) 
        
        self.t_step = (self.t_step + 1)
        if self.t_step % 1 == 0:
            if len(self.memory)>=self.batch_size:
                experiences = self.sample()
                states, actions, rewards, dones, next_states = experiences
                
                Q = self.dqn_learn(states, actions, rewards, dones, next_states)
                self.optimizer_dqn.zero_grad()
                Q.backward()
                torch.nn.utils.clip_grad_norm_(self.dqn.parameters(), 1)
                self.optimizer_dqn.step()
                for target_param, local_param in zip(self.dqn_target.parameters(), self.dqn.parameters()):
                    target_param.data.copy_(0.001*local_param.data + (1.0-0.001)*target_param.data)
                
                P = self.policy_learn(states)
                self.optimizer_policy.zero_grad()
                P.backward()
                self.optimizer_policy.step()
                for target_param, local_param in zip(self.policy_target.parameters(), self.policy.parameters()):
                    target_param.data.copy_(0.001*local_param.data + (1.0-0.001)*target_param.data)
                return Q.cpu().data.numpy(), P.cpu().data.numpy()

    def sample(self):
        experiences = random.sample(self.memory, k=self.batch_size)
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
        return (states, actions, rewards, dones, next_states)
    
    def dqn_learn(self, states, actions, rewards, dones, next_states, discount = 0.99):
        next_actions = self.policy_target(next_states)
        dqn_future_reward = rewards + (discount * self.dqn_target(next_states, next_actions) * (1 - dones))
        dqn_expected_reward = self.dqn(states, actions)
        return F.mse_loss(dqn_future_reward, dqn_expected_reward)
    
    def policy_learn(self, states):
        states = torch.tensor(states, dtype=torch.float)
        actions = self.policy(states)
        rewards = self.dqn(states, actions)
        return -torch.mean(rewards)
    
    def reset(self):
        self.noise.reset()
agent = Agent(int(1e5), 128)

# %%
from workspace_utils import active_session
 
with active_session():
    def training(n_episodes=500, max_t=1000):
        scores = []                        # list containing scores from each episode
        scores_window = deque(maxlen=100)  # last 100 scores
        q_scores_window = deque(maxlen=100)  # last 100 scores
        policy_scores_window = deque(maxlen=100)  # last 100 scores
        for i_episode in range(1, n_episodes+1):
            env_info = env.reset(train_mode = True)[brain_name]
            agent.reset()
            state = env_info.vector_observations[0]
            score = 0
            q_score = 0
            policy_score = 0
            for t in range(max_t):
                action = agent.act(state)
                env_info = env.step(action)[brain_name]           
                next_state, reward, done = env_info.vector_observations[0], env_info.rewards[0], env_info.local_done[0]                        
                score += env_info.rewards[0]                      
                q_learn = agent.step(state, action, reward, done, next_state)
                if q_learn is not None:
                    q, p = q_learn
                    q_score += q
                    policy_score += p
                state = next_state                                # roll over states to next time step
                if done:                                  # exit loop if episode finished
                    break
            scores_window.append(score)       
            q_scores_window.append(q_score)       
            policy_scores_window.append(policy_score)       
            scores.append(score)              
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window, axis = 0)))
            print('\rEpisode {}\tAverage Score Q: {:.2f}'.format(i_episode, np.mean(q_scores_window, axis = 0)))
            print('\rEpisode {}\tAverage Score Policy: {:.2f}'.format(i_episode, np.mean(policy_scores_window, axis = 0)))
            if i_episode % 100 == 0:
                print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            if np.mean(scores_window)>=30.0:
                print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
                torch.save(agent.dqn.state_dict(), 'checkpoint.pth')
                torch.save(agent.policy, 'policy.policy')
                break
        return scores

    scores = training()
# Out:
# Episode 1	Average Score: 1.58
# Episode 1	Average Score Q: 0.00
# Episode 1	Average Score Policy: -20.84
# Episode 2	Average Score: 0.90
# Episode 2	Average Score Q: 0.00
# Episode 2	Average Score Policy: -24.42
# Episode 3	Average Score: 0.90
# Episode 3	Average Score Q: 0.00
# Episode 3	Average Score Policy: -26.69
# Episode 4	Average Score: 0.79
# Episode 4	Average Score Q: 0.01
# Episode 4	Average Score Policy: -28.70
# Episode 5	Average Score: 0.75
# Episode 5	Average Score Q: 0.01
# Episode 5	Average Score Policy: -30.52
# Episode 6	Average Score: 0.70
# Episode 6	Average Score Q: 0.01
# Episode 6	Average Score Policy: -32.17
# Episode 7	Average Score: 0.65
# Episode 7	Average Score Q: 0.01
# Episode 7	Average Score Policy: -33.78
# Episode 8	Average Score: 0.74
# Episode 8	Average Score Q: 0.01
# Episode 8	Average Score Policy: -35.32
# Episode 9	Average Score: 0.84
# Episode 9	Average Score Q: 0.01
# Episode 9	Average Score Policy: -36.84
# Episode 10	Average Score: 1.01
# Episode 10	Average Score Q: 0.01
# Episode 10	Average Score Policy: -38.38
# Episode 11	Average Score: 1.07
# Episode 11	Average Score Q: 0.01
# Episode 11	Average Score Policy: -39.95
# Episode 12	Average Score: 1.11
# Episode 12	Average Score Q: 0.01
# Episode 12	Average Score Policy: -41.54
# Episode 13	Average Score: 1.07
# Episode 13	Average Score Q: 0.02
# Episode 13	Average Score Policy: -43.12
# Episode 14	Average Score: 1.11
# Episode 14	Average Score Q: 0.02
# Episode 14	Average Score Policy: -44.70
# Episode 15	Average Score: 1.10
# Episode 15	Average Score Q: 0.02
# Episode 15	Average Score Policy: -46.29
# Episode 16	Average Score: 1.05
# Episode 16	Average Score Q: 0.02
# Episode 16	Average Score Policy: -47.88
# Episode 17	Average Score: 1.09
# Episode 17	Average Score Q: 0.02
# Episode 17	Average Score Policy: -49.46
# Episode 18	Average Score: 1.11
# Episode 18	Average Score Q: 0.02
# Episode 18	Average Score Policy: -51.06
# Episode 19	Average Score: 1.11
# Episode 19	Average Score Q: 0.03
# Episode 19	Average Score Policy: -52.67
# Episode 20	Average Score: 1.21
# Episode 20	Average Score Q: 0.03
# Episode 20	Average Score Policy: -54.26
# Episode 21	Average Score: 1.20
# Episode 21	Average Score Q: 0.03
# Episode 21	Average Score Policy: -55.87
# Episode 22	Average Score: 1.25
# Episode 22	Average Score Q: 0.03
# Episode 22	Average Score Policy: -57.50
# Episode 23	Average Score: 1.30
# Episode 23	Average Score Q: 0.04
# Episode 23	Average Score Policy: -59.16
# Episode 24	Average Score: 1.33
# Episode 24	Average Score Q: 0.04
# Episode 24	Average Score Policy: -60.85
# Episode 25	Average Score: 1.38
# Episode 25	Average Score Q: 0.04
# Episode 25	Average Score Policy: -62.57
# Episode 26	Average Score: 1.44
# Episode 26	Average Score Q: 0.04
# Episode 26	Average Score Policy: -64.31
# Episode 27	Average Score: 1.46
# Episode 27	Average Score Q: 0.05
# Episode 27	Average Score Policy: -66.08
# Episode 28	Average Score: 1.48
# Episode 28	Average Score Q: 0.05
# Episode 28	Average Score Policy: -67.87
# Episode 29	Average Score: 1.51
# Episode 29	Average Score Q: 0.05
# Episode 29	Average Score Policy: -69.69
# Episode 30	Average Score: 1.51
# Episode 30	Average Score Q: 0.06
# Episode 30	Average Score Policy: -71.54
# Episode 31	Average Score: 1.54
# Episode 31	Average Score Q: 0.06
# Episode 31	Average Score Policy: -73.44
# Episode 32	Average Score: 1.64
# Episode 32	Average Score Q: 0.06
# Episode 32	Average Score Policy: -75.37
# Episode 33	Average Score: 1.67
# Episode 33	Average Score Q: 0.07
# Episode 33	Average Score Policy: -77.34
# Episode 34	Average Score: 1.70
# Episode 34	Average Score Q: 0.07
# Episode 34	Average Score Policy: -79.35
# Episode 35	Average Score: 1.73
# Episode 35	Average Score Q: 0.08
# Episode 35	Average Score Policy: -81.40
# Episode 36	Average Score: 1.73
# Episode 36	Average Score Q: 0.08
# Episode 36	Average Score Policy: -83.47
# Episode 37	Average Score: 1.75
# Episode 37	Average Score Q: 0.09
# Episode 37	Average Score Policy: -85.56
# Episode 38	Average Score: 1.74
# Episode 38	Average Score Q: 0.09
# Episode 38	Average Score Policy: -87.68
# Episode 39	Average Score: 1.79
# Episode 39	Average Score Q: 0.09
# Episode 39	Average Score Policy: -89.82
# Episode 40	Average Score: 1.83
# Episode 40	Average Score Q: 0.10
# Episode 40	Average Score Policy: -91.97
# Episode 41	Average Score: 1.82
# Episode 41	Average Score Q: 0.10
# Episode 41	Average Score Policy: -94.14
# Episode 42	Average Score: 1.86
# Episode 42	Average Score Q: 0.11
# Episode 42	Average Score Policy: -96.34
# Episode 43	Average Score: 1.86
# Episode 43	Average Score Q: 0.11
# Episode 43	Average Score Policy: -98.55
# Episode 44	Average Score: 1.87
# Episode 44	Average Score Q: 0.12
# Episode 44	Average Score Policy: -100.78
# Episode 45	Average Score: 1.87
# Episode 45	Average Score Q: 0.12
# Episode 45	Average Score Policy: -103.03
# Episode 46	Average Score: 1.90
# Episode 46	Average Score Q: 0.12
# Episode 46	Average Score Policy: -105.29
# Episode 47	Average Score: 1.95
# Episode 47	Average Score Q: 0.13
# Episode 47	Average Score Policy: -107.57
# Episode 48	Average Score: 1.96
# Episode 48	Average Score Q: 0.13
# Episode 48	Average Score Policy: -109.88
# Episode 49	Average Score: 1.95
# Episode 49	Average Score Q: 0.14
# Episode 49	Average Score Policy: -112.21
# Episode 50	Average Score: 1.99
# Episode 50	Average Score Q: 0.14
# Episode 50	Average Score Policy: -114.53
# Episode 51	Average Score: 2.00
# Episode 51	Average Score Q: 0.15
# Episode 51	Average Score Policy: -116.87
# Episode 52	Average Score: 2.04
# Episode 52	Average Score Q: 0.15
# Episode 52	Average Score Policy: -119.21
# Episode 53	Average Score: 2.08
# Episode 53	Average Score Q: 0.15
# Episode 53	Average Score Policy: -121.56
# Episode 54	Average Score: 2.10
# Episode 54	Average Score Q: 0.16
# Episode 54	Average Score Policy: -123.92
# Episode 55	Average Score: 2.13
# Episode 55	Average Score Q: 0.16
# Episode 55	Average Score Policy: -126.29
# Episode 56	Average Score: 2.18
# Episode 56	Average Score Q: 0.17
# Episode 56	Average Score Policy: -128.67
# Episode 57	Average Score: 2.22
# Episode 57	Average Score Q: 0.17
# Episode 57	Average Score Policy: -131.05
# Episode 58	Average Score: 2.23
# Episode 58	Average Score Q: 0.18
# Episode 58	Average Score Policy: -133.45
# Episode 59	Average Score: 2.26
# Episode 59	Average Score Q: 0.18
# Episode 59	Average Score Policy: -135.86
# Episode 60	Average Score: 2.27
# Episode 60	Average Score Q: 0.18
# Episode 60	Average Score Policy: -138.27
# Episode 61	Average Score: 2.27
# Episode 61	Average Score Q: 0.19
# Episode 61	Average Score Policy: -140.69
# Episode 62	Average Score: 2.34
# Episode 62	Average Score Q: 0.19
# Episode 62	Average Score Policy: -143.12
# Episode 63	Average Score: 2.37
# Episode 63	Average Score Q: 0.20
# Episode 63	Average Score Policy: -145.55
# Episode 64	Average Score: 2.39
# Episode 64	Average Score Q: 0.20
# Episode 64	Average Score Policy: -148.00
# Episode 65	Average Score: 2.39
# Episode 65	Average Score Q: 0.20
# Episode 65	Average Score Policy: -150.44
# Episode 66	Average Score: 2.42
# Episode 66	Average Score Q: 0.21
# Episode 66	Average Score Policy: -152.90
# Episode 67	Average Score: 2.42
# Episode 67	Average Score Q: 0.21
# Episode 67	Average Score Policy: -155.36
# Episode 68	Average Score: 2.44
# Episode 68	Average Score Q: 0.22
# Episode 68	Average Score Policy: -157.82
# Episode 69	Average Score: 2.44
# Episode 69	Average Score Q: 0.22
# Episode 69	Average Score Policy: -160.28
# Episode 70	Average Score: 2.41
# Episode 70	Average Score Q: 0.22
# Episode 70	Average Score Policy: -162.73
# Episode 71	Average Score: 2.42
# Episode 71	Average Score Q: 0.23
# Episode 71	Average Score Policy: -165.18
# Episode 72	Average Score: 2.40
# Episode 72	Average Score Q: 0.23
# Episode 72	Average Score Policy: -167.62
# Episode 73	Average Score: 2.41
# Episode 73	Average Score Q: 0.23
# Episode 73	Average Score Policy: -170.06
# Episode 74	Average Score: 2.41
# Episode 74	Average Score Q: 0.24
# Episode 74	Average Score Policy: -172.48
# Episode 75	Average Score: 2.44
# Episode 75	Average Score Q: 0.24
# Episode 75	Average Score Policy: -174.90
# Episode 76	Average Score: 2.48
# Episode 76	Average Score Q: 0.25
# Episode 76	Average Score Policy: -177.30
# Episode 77	Average Score: 2.49
# Episode 77	Average Score Q: 0.25
# Episode 77	Average Score Policy: -179.69
# Episode 78	Average Score: 2.49
# Episode 78	Average Score Q: 0.25
# Episode 78	Average Score Policy: -182.08
# Episode 79	Average Score: 2.52
# Episode 79	Average Score Q: 0.26
# Episode 79	Average Score Policy: -184.45
# Episode 80	Average Score: 2.54
# Episode 80	Average Score Q: 0.26
# Episode 80	Average Score Policy: -186.83
# Episode 81	Average Score: 2.58
# Episode 81	Average Score Q: 0.26
# Episode 81	Average Score Policy: -189.19
# Episode 82	Average Score: 2.59
# Episode 82	Average Score Q: 0.27
# Episode 82	Average Score Policy: -191.56
# Episode 83	Average Score: 2.61
# Episode 83	Average Score Q: 0.27
# Episode 83	Average Score Policy: -193.91
# Episode 84	Average Score: 2.62
# Episode 84	Average Score Q: 0.27
# Episode 84	Average Score Policy: -196.27
# Episode 85	Average Score: 2.65
# Episode 85	Average Score Q: 0.27
# Episode 85	Average Score Policy: -198.63
# Episode 86	Average Score: 2.69
# Episode 86	Average Score Q: 0.28
# Episode 86	Average Score Policy: -200.99
# Episode 87	Average Score: 2.72
# Episode 87	Average Score Q: 0.28
# Episode 87	Average Score Policy: -203.34
# Episode 88	Average Score: 2.77
# Episode 88	Average Score Q: 0.28
# Episode 88	Average Score Policy: -205.69
# Episode 89	Average Score: 2.79
# Episode 89	Average Score Q: 0.29
# Episode 89	Average Score Policy: -208.04
# Episode 90	Average Score: 2.84
# Episode 90	Average Score Q: 0.29
# Episode 90	Average Score Policy: -210.40
# Episode 91	Average Score: 2.84
# Episode 91	Average Score Q: 0.29
# Episode 91	Average Score Policy: -212.75
# Episode 92	Average Score: 2.89
# Episode 92	Average Score Q: 0.30
# Episode 92	Average Score Policy: -215.10
# Episode 93	Average Score: 2.93
# Episode 93	Average Score Q: 0.30
# Episode 93	Average Score Policy: -217.44
# Episode 94	Average Score: 2.97
# Episode 94	Average Score Q: 0.30
# Episode 94	Average Score Policy: -219.77
# Episode 95	Average Score: 3.01
# Episode 95	Average Score Q: 0.31
# Episode 95	Average Score Policy: -222.10
# Episode 96	Average Score: 3.03
# Episode 96	Average Score Q: 0.31
# Episode 96	Average Score Policy: -224.43
# Episode 97	Average Score: 3.03
# Episode 97	Average Score Q: 0.31
# Episode 97	Average Score Policy: -226.75
# Episode 98	Average Score: 3.05
# Episode 98	Average Score Q: 0.32
# Episode 98	Average Score Policy: -229.07
# Episode 99	Average Score: 3.05
# Episode 99	Average Score Q: 0.32
# Episode 99	Average Score Policy: -231.38
# Episode 100	Average Score: 3.08
# Episode 100	Average Score Q: 0.32
# Episode 100	Average Score Policy: -233.69
# Episode 100	Average Score: 3.08
# Episode 101	Average Score: 3.11
# Episode 101	Average Score Q: 0.33
# Episode 101	Average Score Policy: -238.16
# Episode 102	Average Score: 3.20
# Episode 102	Average Score Q: 0.34
# Episode 102	Average Score Policy: -242.61
# Episode 103	Average Score: 3.23
# Episode 103	Average Score Q: 0.34
# Episode 103	Average Score Policy: -247.07
# Episode 104	Average Score: 3.28
# Episode 104	Average Score Q: 0.35
# Episode 104	Average Score Policy: -251.56
# Episode 105	Average Score: 3.33
# Episode 105	Average Score Q: 0.36
# Episode 105	Average Score Policy: -256.06
# Episode 106	Average Score: 3.37
# Episode 106	Average Score Q: 0.36
# Episode 106	Average Score Policy: -260.59
# Episode 107	Average Score: 3.43
# Episode 107	Average Score Q: 0.37
# Episode 107	Average Score Policy: -265.14
# Episode 108	Average Score: 3.48
# Episode 108	Average Score Q: 0.38
# Episode 108	Average Score Policy: -269.72
# Episode 109	Average Score: 3.51
# Episode 109	Average Score Q: 0.38
# Episode 109	Average Score Policy: -274.32
# Episode 110	Average Score: 3.54
# Episode 110	Average Score Q: 0.39
# Episode 110	Average Score Policy: -278.93
# Episode 111	Average Score: 3.60
# Episode 111	Average Score Q: 0.40
# Episode 111	Average Score Policy: -283.56
# Episode 112	Average Score: 3.68
# Episode 112	Average Score Q: 0.40
# Episode 112	Average Score Policy: -288.21
# Episode 113	Average Score: 3.74
# Episode 113	Average Score Q: 0.41
# Episode 113	Average Score Policy: -292.89
# Episode 114	Average Score: 3.80
# Episode 114	Average Score Q: 0.42
# Episode 114	Average Score Policy: -297.59
# Episode 115	Average Score: 3.83
# Episode 115	Average Score Q: 0.43
# Episode 115	Average Score Policy: -302.30
# Episode 116	Average Score: 3.93
# Episode 116	Average Score Q: 0.43
# Episode 116	Average Score Policy: -307.04
# Episode 117	Average Score: 3.99
# Episode 117	Average Score Q: 0.44
# Episode 117	Average Score Policy: -311.78
# Episode 118	Average Score: 4.04
# Episode 118	Average Score Q: 0.45
# Episode 118	Average Score Policy: -316.55
# Episode 119	Average Score: 4.09
# Episode 119	Average Score Q: 0.46
# Episode 119	Average Score Policy: -321.34
# Episode 120	Average Score: 4.12
# Episode 120	Average Score Q: 0.46
# Episode 120	Average Score Policy: -326.15
# Episode 121	Average Score: 4.15
# Episode 121	Average Score Q: 0.47
# Episode 121	Average Score Policy: -330.98
# Episode 122	Average Score: 4.19
# Episode 122	Average Score Q: 0.48
# Episode 122	Average Score Policy: -335.82
# Episode 123	Average Score: 4.25
# Episode 123	Average Score Q: 0.49
# Episode 123	Average Score Policy: -340.68
# Episode 124	Average Score: 4.27
# Episode 124	Average Score Q: 0.50
# Episode 124	Average Score Policy: -345.55
# Episode 125	Average Score: 4.30
# Episode 125	Average Score Q: 0.50
# Episode 125	Average Score Policy: -350.43
# Episode 126	Average Score: 4.32
# Episode 126	Average Score Q: 0.51
# Episode 126	Average Score Policy: -355.32
# Episode 127	Average Score: 4.34
# Episode 127	Average Score Q: 0.52
# Episode 127	Average Score Policy: -360.21
# Episode 128	Average Score: 4.37
# Episode 128	Average Score Q: 0.53
# Episode 128	Average Score Policy: -365.12
# Episode 129	Average Score: 4.39
# Episode 129	Average Score Q: 0.54
# Episode 129	Average Score Policy: -370.04
# Episode 130	Average Score: 4.46
# Episode 130	Average Score Q: 0.54
# Episode 130	Average Score Policy: -374.95
# Episode 131	Average Score: 4.48
# Episode 131	Average Score Q: 0.55
# Episode 131	Average Score Policy: -379.87
# Episode 132	Average Score: 4.49
# Episode 132	Average Score Q: 0.56
# Episode 132	Average Score Policy: -384.78
# Episode 133	Average Score: 4.54
# Episode 133	Average Score Q: 0.57
# Episode 133	Average Score Policy: -389.69
# Episode 134	Average Score: 4.53
# Episode 134	Average Score Q: 0.57
# Episode 134	Average Score Policy: -394.61
# Episode 135	Average Score: 4.59
# Episode 135	Average Score Q: 0.58
# Episode 135	Average Score Policy: -399.52
# Episode 136	Average Score: 4.67
# Episode 136	Average Score Q: 0.59
# Episode 136	Average Score Policy: -404.42
# Episode 137	Average Score: 4.72
# Episode 137	Average Score Q: 0.60
# Episode 137	Average Score Policy: -409.33
# Episode 138	Average Score: 4.87
# Episode 138	Average Score Q: 0.61
# Episode 138	Average Score Policy: -414.25
# Episode 139	Average Score: 4.95
# Episode 139	Average Score Q: 0.61
# Episode 139	Average Score Policy: -419.18
# Episode 140	Average Score: 5.02
# Episode 140	Average Score Q: 0.62
# Episode 140	Average Score Policy: -424.12
# Episode 141	Average Score: 5.10
# Episode 141	Average Score Q: 0.63
# Episode 141	Average Score Policy: -429.08
# Episode 142	Average Score: 5.19
# Episode 142	Average Score Q: 0.64
# Episode 142	Average Score Policy: -434.05
# Episode 143	Average Score: 5.22
# Episode 143	Average Score Q: 0.65
# Episode 143	Average Score Policy: -439.03
# Episode 144	Average Score: 5.30
# Episode 144	Average Score Q: 0.66
# Episode 144	Average Score Policy: -444.02
# Episode 145	Average Score: 5.44
# Episode 145	Average Score Q: 0.67
# Episode 145	Average Score Policy: -449.03
# Episode 146	Average Score: 5.61
# Episode 146	Average Score Q: 0.67
# Episode 146	Average Score Policy: -454.05
# Episode 147	Average Score: 5.66
# Episode 147	Average Score Q: 0.68
# Episode 147	Average Score Policy: -459.09
# Episode 148	Average Score: 5.71
# Episode 148	Average Score Q: 0.69
# Episode 148	Average Score Policy: -464.14
# Episode 149	Average Score: 5.76
# Episode 149	Average Score Q: 0.70
# Episode 149	Average Score Policy: -469.19
# Episode 150	Average Score: 5.77
# Episode 150	Average Score Q: 0.71
# Episode 150	Average Score Policy: -474.27
# Episode 151	Average Score: 5.91
# Episode 151	Average Score Q: 0.72
# Episode 151	Average Score Policy: -479.37
# Episode 152	Average Score: 6.01
# Episode 152	Average Score Q: 0.73
# Episode 152	Average Score Policy: -484.50
# Episode 153	Average Score: 6.04
# Episode 153	Average Score Q: 0.74
# Episode 153	Average Score Policy: -489.65
# Episode 154	Average Score: 6.11
# Episode 154	Average Score Q: 0.75
# Episode 154	Average Score Policy: -494.83
# Episode 155	Average Score: 6.19
# Episode 155	Average Score Q: 0.76
# Episode 155	Average Score Policy: -500.04
# Episode 156	Average Score: 6.23
# Episode 156	Average Score Q: 0.77
# Episode 156	Average Score Policy: -505.26
# Episode 157	Average Score: 6.31
# Episode 157	Average Score Q: 0.78
# Episode 157	Average Score Policy: -510.51
# Episode 158	Average Score: 6.37
# Episode 158	Average Score Q: 0.79
# Episode 158	Average Score Policy: -515.78
# Episode 159	Average Score: 6.41
# Episode 159	Average Score Q: 0.80
# Episode 159	Average Score Policy: -521.08
# Episode 160	Average Score: 6.63
# Episode 160	Average Score Q: 0.81
# Episode 160	Average Score Policy: -526.40
# Episode 161	Average Score: 6.78
# Episode 161	Average Score Q: 0.83
# Episode 161	Average Score Policy: -531.77
# Episode 162	Average Score: 6.88
# Episode 162	Average Score Q: 0.84
# Episode 162	Average Score Policy: -537.17
# Episode 163	Average Score: 6.89
# Episode 163	Average Score Q: 0.85
# Episode 163	Average Score Policy: -542.60
# Episode 164	Average Score: 6.95
# Episode 164	Average Score Q: 0.86
# Episode 164	Average Score Policy: -548.07
# Episode 165	Average Score: 7.06
# Episode 165	Average Score Q: 0.87
# Episode 165	Average Score Policy: -553.59
# Episode 166	Average Score: 7.15
# Episode 166	Average Score Q: 0.89
# Episode 166	Average Score Policy: -559.14
# Episode 167	Average Score: 7.23
# Episode 167	Average Score Q: 0.90
# Episode 167	Average Score Policy: -564.73
# Episode 168	Average Score: 7.42
# Episode 168	Average Score Q: 0.91
# Episode 168	Average Score Policy: -570.37
# Episode 169	Average Score: 7.57
# Episode 169	Average Score Q: 0.93
# Episode 169	Average Score Policy: -576.07
# Episode 170	Average Score: 7.63
# Episode 170	Average Score Q: 0.94
# Episode 170	Average Score Policy: -581.84
# Episode 171	Average Score: 7.66
# Episode 171	Average Score Q: 0.96
# Episode 171	Average Score Policy: -587.66
# Episode 172	Average Score: 7.71
# Episode 172	Average Score Q: 0.97
# Episode 172	Average Score Policy: -593.53
# Episode 173	Average Score: 7.82
# Episode 173	Average Score Q: 0.99
# Episode 173	Average Score Policy: -599.47
# Episode 174	Average Score: 7.83
# Episode 174	Average Score Q: 1.00
# Episode 174	Average Score Policy: -605.45
# Episode 175	Average Score: 7.95
# Episode 175	Average Score Q: 1.02
# Episode 175	Average Score Policy: -611.50
# Episode 176	Average Score: 7.98
# Episode 176	Average Score Q: 1.03
# Episode 176	Average Score Policy: -617.63
# Episode 177	Average Score: 8.02
# Episode 177	Average Score Q: 1.05
# Episode 177	Average Score Policy: -623.80
# Episode 178	Average Score: 8.07
# Episode 178	Average Score Q: 1.07
# Episode 178	Average Score Policy: -630.03
# Episode 179	Average Score: 8.14
# Episode 179	Average Score Q: 1.08
# Episode 179	Average Score Policy: -636.31
# Episode 180	Average Score: 8.21
# Episode 180	Average Score Q: 1.10
# Episode 180	Average Score Policy: -642.66
# Episode 181	Average Score: 8.23
# Episode 181	Average Score Q: 1.12
# Episode 181	Average Score Policy: -649.08
# Episode 182	Average Score: 8.34
# Episode 182	Average Score Q: 1.14
# Episode 182	Average Score Policy: -655.55
# Episode 183	Average Score: 8.53
# Episode 183	Average Score Q: 1.16
# Episode 183	Average Score Policy: -662.11
# Episode 184	Average Score: 8.62
# Episode 184	Average Score Q: 1.18
# Episode 184	Average Score Policy: -668.74
# Episode 185	Average Score: 8.75
# Episode 185	Average Score Q: 1.20
# Episode 185	Average Score Policy: -675.45
# Episode 186	Average Score: 8.86
# Episode 186	Average Score Q: 1.22
# Episode 186	Average Score Policy: -682.23
# Episode 187	Average Score: 9.11
# Episode 187	Average Score Q: 1.24
# Episode 187	Average Score Policy: -689.08
# Episode 188	Average Score: 9.30
# Episode 188	Average Score Q: 1.26
# Episode 188	Average Score Policy: -696.04
# Episode 189	Average Score: 9.58
# Episode 189	Average Score Q: 1.28
# Episode 189	Average Score Policy: -703.08
# Episode 190	Average Score: 9.85
# Episode 190	Average Score Q: 1.30
# Episode 190	Average Score Policy: -710.21
# Episode 191	Average Score: 9.91
# Episode 191	Average Score Q: 1.32
# Episode 191	Average Score Policy: -717.45
# Episode 192	Average Score: 10.10
# Episode 192	Average Score Q: 1.35
# Episode 192	Average Score Policy: -724.77
# Episode 193	Average Score: 10.17
# Episode 193	Average Score Q: 1.37
# Episode 193	Average Score Policy: -732.18
# Episode 194	Average Score: 10.39
# Episode 194	Average Score Q: 1.39
# Episode 194	Average Score Policy: -739.71
# Episode 195	Average Score: 10.62
# Episode 195	Average Score Q: 1.41
# Episode 195	Average Score Policy: -747.34
# Episode 196	Average Score: 10.73
# Episode 196	Average Score Q: 1.44
# Episode 196	Average Score Policy: -755.03
# Episode 197	Average Score: 10.77
# Episode 197	Average Score Q: 1.46
# Episode 197	Average Score Policy: -762.81
# Episode 198	Average Score: 11.07
# Episode 198	Average Score Q: 1.48
# Episode 198	Average Score Policy: -770.68
# Episode 199	Average Score: 11.29
# Episode 199	Average Score Q: 1.50
# Episode 199	Average Score Policy: -778.65
# Episode 200	Average Score: 11.57
# Episode 200	Average Score Q: 1.53
# Episode 200	Average Score Policy: -786.75
# Episode 200	Average Score: 11.57
# Episode 201	Average Score: 11.58
# Episode 201	Average Score Q: 1.55
# Episode 201	Average Score Policy: -794.95
# Episode 202	Average Score: 11.83
# Episode 202	Average Score Q: 1.57
# Episode 202	Average Score Policy: -803.25
# Episode 203	Average Score: 12.06
# Episode 203	Average Score Q: 1.60
# Episode 203	Average Score Policy: -811.66
# Episode 204	Average Score: 12.15
# Episode 204	Average Score Q: 1.62
# Episode 204	Average Score Policy: -820.18
# Episode 205	Average Score: 12.37
# Episode 205	Average Score Q: 1.64
# Episode 205	Average Score Policy: -828.76
# Episode 206	Average Score: 12.53
# Episode 206	Average Score Q: 1.67
# Episode 206	Average Score Policy: -837.46
# Episode 207	Average Score: 12.68
# Episode 207	Average Score Q: 1.69
# Episode 207	Average Score Policy: -846.26
# Episode 208	Average Score: 12.75
# Episode 208	Average Score Q: 1.71
# Episode 208	Average Score Policy: -855.15
# Episode 209	Average Score: 13.08
# Episode 209	Average Score Q: 1.74
# Episode 209	Average Score Policy: -864.17
# Episode 210	Average Score: 13.17
# Episode 210	Average Score Q: 1.76
# Episode 210	Average Score Policy: -873.28
# Episode 211	Average Score: 13.49
# Episode 211	Average Score Q: 1.79
# Episode 211	Average Score Policy: -882.50
# Episode 212	Average Score: 13.48
# Episode 212	Average Score Q: 1.81
# Episode 212	Average Score Policy: -891.82
# Episode 213	Average Score: 13.52
# Episode 213	Average Score Q: 1.84
# Episode 213	Average Score Policy: -901.25
# Episode 214	Average Score: 13.80
# Episode 214	Average Score Q: 1.86
# Episode 214	Average Score Policy: -910.78
# Episode 215	Average Score: 13.99
# Episode 215	Average Score Q: 1.88
# Episode 215	Average Score Policy: -920.42
# Episode 216	Average Score: 14.25
# Episode 216	Average Score Q: 1.91
# Episode 216	Average Score Policy: -930.19
# Episode 217	Average Score: 14.41
# Episode 217	Average Score Q: 1.93
# Episode 217	Average Score Policy: -940.08
# Episode 218	Average Score: 14.67
# Episode 218	Average Score Q: 1.96
# Episode 218	Average Score Policy: -950.08
# Episode 219	Average Score: 14.99
# Episode 219	Average Score Q: 1.98
# Episode 219	Average Score Policy: -960.17
# Episode 220	Average Score: 15.12
# Episode 220	Average Score Q: 2.01
# Episode 220	Average Score Policy: -970.40
# Episode 221	Average Score: 15.23
# Episode 221	Average Score Q: 2.04
# Episode 221	Average Score Policy: -980.71
# Episode 222	Average Score: 15.56
# Episode 222	Average Score Q: 2.06
# Episode 222	Average Score Policy: -991.15
# Episode 223	Average Score: 15.52
# Episode 223	Average Score Q: 2.09
# Episode 223	Average Score Policy: -1001.69
# Episode 224	Average Score: 15.57
# Episode 224	Average Score Q: 2.11
# Episode 224	Average Score Policy: -1012.34
# Episode 225	Average Score: 15.88
# Episode 225	Average Score Q: 2.14
# Episode 225	Average Score Policy: -1023.10
# Episode 226	Average Score: 16.09
# Episode 226	Average Score Q: 2.16
# Episode 226	Average Score Policy: -1033.99
# Episode 227	Average Score: 16.11
# Episode 227	Average Score Q: 2.19
# Episode 227	Average Score Policy: -1045.01
# Episode 228	Average Score: 16.40
# Episode 228	Average Score Q: 2.21
# Episode 228	Average Score Policy: -1056.14
# Episode 229	Average Score: 16.74
# Episode 229	Average Score Q: 2.24
# Episode 229	Average Score Policy: -1067.40
# Episode 230	Average Score: 16.94
# Episode 230	Average Score Q: 2.26
# Episode 230	Average Score Policy: -1078.82
# Episode 231	Average Score: 17.24
# Episode 231	Average Score Q: 2.28
# Episode 231	Average Score Policy: -1090.36
# Episode 232	Average Score: 17.36
# Episode 232	Average Score Q: 2.31
# Episode 232	Average Score Policy: -1102.07
# Episode 233	Average Score: 17.54
# Episode 233	Average Score Q: 2.33
# Episode 233	Average Score Policy: -1113.88
# Episode 234	Average Score: 17.85
# Episode 234	Average Score Q: 2.36
# Episode 234	Average Score Policy: -1125.83
# Episode 235	Average Score: 18.10
# Episode 235	Average Score Q: 2.38
# Episode 235	Average Score Policy: -1137.93
# Episode 236	Average Score: 18.36
# Episode 236	Average Score Q: 2.41
# Episode 236	Average Score Policy: -1150.17
# Episode 237	Average Score: 18.46
# Episode 237	Average Score Q: 2.43
# Episode 237	Average Score Policy: -1162.52
# Episode 238	Average Score: 18.65
# Episode 238	Average Score Q: 2.45
# Episode 238	Average Score Policy: -1175.00
# Episode 239	Average Score: 18.79
# Episode 239	Average Score Q: 2.48
# Episode 239	Average Score Policy: -1187.60
# Episode 240	Average Score: 19.05
# Episode 240	Average Score Q: 2.50
# Episode 240	Average Score Policy: -1200.34
# Episode 241	Average Score: 19.16
# Episode 241	Average Score Q: 2.52
# Episode 241	Average Score Policy: -1213.20
# Episode 242	Average Score: 19.35
# Episode 242	Average Score Q: 2.54
# Episode 242	Average Score Policy: -1226.15
# Episode 243	Average Score: 19.53
# Episode 243	Average Score Q: 2.56
# Episode 243	Average Score Policy: -1239.20
# Episode 244	Average Score: 19.67
# Episode 244	Average Score Q: 2.58
# Episode 244	Average Score Policy: -1252.35
# Episode 245	Average Score: 19.77
# Episode 245	Average Score Q: 2.61
# Episode 245	Average Score Policy: -1265.59
# Episode 246	Average Score: 19.81
# Episode 246	Average Score Q: 2.63
# Episode 246	Average Score Policy: -1278.94
# Episode 247	Average Score: 20.04
# Episode 247	Average Score Q: 2.65
# Episode 247	Average Score Policy: -1292.39
# Episode 248	Average Score: 20.32
# Episode 248	Average Score Q: 2.67
# Episode 248	Average Score Policy: -1305.96
# Episode 249	Average Score: 20.56
# Episode 249	Average Score Q: 2.69
# Episode 249	Average Score Policy: -1319.63
# Episode 250	Average Score: 20.79
# Episode 250	Average Score Q: 2.71
# Episode 250	Average Score Policy: -1333.44
# Episode 251	Average Score: 21.01
# Episode 251	Average Score Q: 2.73
# Episode 251	Average Score Policy: -1347.37
# Episode 252	Average Score: 21.05
# Episode 252	Average Score Q: 2.75
# Episode 252	Average Score Policy: -1361.40
# Episode 253	Average Score: 21.12
# Episode 253	Average Score Q: 2.77
# Episode 253	Average Score Policy: -1375.53
# Episode 254	Average Score: 21.33
# Episode 254	Average Score Q: 2.79
# Episode 254	Average Score Policy: -1389.76
# Episode 255	Average Score: 21.59
# Episode 255	Average Score Q: 2.81
# Episode 255	Average Score Policy: -1404.09
# Episode 256	Average Score: 21.84
# Episode 256	Average Score Q: 2.83
# Episode 256	Average Score Policy: -1418.54
# Episode 257	Average Score: 22.00
# Episode 257	Average Score Q: 2.85
# Episode 257	Average Score Policy: -1433.13
# Episode 258	Average Score: 22.25
# Episode 258	Average Score Q: 2.87
# Episode 258	Average Score Policy: -1447.82
# Episode 259	Average Score: 22.44
# Episode 259	Average Score Q: 2.89
# Episode 259	Average Score Policy: -1462.61
# Episode 260	Average Score: 22.48
# Episode 260	Average Score Q: 2.90
# Episode 260	Average Score Policy: -1477.50
# Episode 261	Average Score: 22.66
# Episode 261	Average Score Q: 2.92
# Episode 261	Average Score Policy: -1492.44
# Episode 262	Average Score: 22.87
# Episode 262	Average Score Q: 2.94
# Episode 262	Average Score Policy: -1507.49
# Episode 263	Average Score: 22.99
# Episode 263	Average Score Q: 2.96
# Episode 263	Average Score Policy: -1522.66
# Episode 264	Average Score: 23.24
# Episode 264	Average Score Q: 2.97
# Episode 264	Average Score Policy: -1537.89
# Episode 265	Average Score: 23.37
# Episode 265	Average Score Q: 2.99
# Episode 265	Average Score Policy: -1553.18
# Episode 266	Average Score: 23.61
# Episode 266	Average Score Q: 3.00
# Episode 266	Average Score Policy: -1568.60
# Episode 267	Average Score: 23.84
# Episode 267	Average Score Q: 3.02
# Episode 267	Average Score Policy: -1584.09
# Episode 268	Average Score: 23.95
# Episode 268	Average Score Q: 3.03
# Episode 268	Average Score Policy: -1599.66
# Episode 269	Average Score: 24.13
# Episode 269	Average Score Q: 3.05
# Episode 269	Average Score Policy: -1615.33
# Episode 270	Average Score: 24.43
# Episode 270	Average Score Q: 3.06
# Episode 270	Average Score Policy: -1631.07
# Episode 271	Average Score: 24.67
# Episode 271	Average Score Q: 3.07
# Episode 271	Average Score Policy: -1646.88
# Episode 272	Average Score: 24.89
# Episode 272	Average Score Q: 3.09
# Episode 272	Average Score Policy: -1662.80
# Episode 273	Average Score: 24.89
# Episode 273	Average Score Q: 3.10
# Episode 273	Average Score Policy: -1678.78
# Episode 274	Average Score: 25.20
# Episode 274	Average Score Q: 3.11
# Episode 274	Average Score Policy: -1694.84
# Episode 275	Average Score: 25.28
# Episode 275	Average Score Q: 3.13
# Episode 275	Average Score Policy: -1710.98
# Episode 276	Average Score: 25.30
# Episode 276	Average Score Q: 3.14
# Episode 276	Average Score Policy: -1727.18
# Episode 277	Average Score: 25.53
# Episode 277	Average Score Q: 3.15
# Episode 277	Average Score Policy: -1743.44
# Episode 278	Average Score: 25.82
# Episode 278	Average Score Q: 3.16
# Episode 278	Average Score Policy: -1759.80
# Episode 279	Average Score: 26.07
# Episode 279	Average Score Q: 3.17
# Episode 279	Average Score Policy: -1776.26
# Episode 280	Average Score: 26.13
# Episode 280	Average Score Q: 3.18
# Episode 280	Average Score Policy: -1792.79
# Episode 281	Average Score: 26.43
# Episode 281	Average Score Q: 3.19
# Episode 281	Average Score Policy: -1809.43
# Episode 282	Average Score: 26.49
# Episode 282	Average Score Q: 3.20
# Episode 282	Average Score Policy: -1826.14
# Episode 283	Average Score: 26.62
# Episode 283	Average Score Q: 3.21
# Episode 283	Average Score Policy: -1842.89
# Episode 284	Average Score: 26.80
# Episode 284	Average Score Q: 3.21
# Episode 284	Average Score Policy: -1859.74
# Episode 285	Average Score: 26.86
# Episode 285	Average Score Q: 3.22
# Episode 285	Average Score Policy: -1876.66
# Episode 286	Average Score: 27.08
# Episode 286	Average Score Q: 3.23
# Episode 286	Average Score Policy: -1893.62
# Episode 287	Average Score: 27.13
# Episode 287	Average Score Q: 3.23
# Episode 287	Average Score Policy: -1910.67
# Episode 288	Average Score: 27.21
# Episode 288	Average Score Q: 3.24
# Episode 288	Average Score Policy: -1927.75
# Episode 289	Average Score: 27.14
# Episode 289	Average Score Q: 3.24
# Episode 289	Average Score Policy: -1944.89
# Episode 290	Average Score: 27.05
# Episode 290	Average Score Q: 3.24
# Episode 290	Average Score Policy: -1962.01
# Episode 291	Average Score: 27.32
# Episode 291	Average Score Q: 3.25
# Episode 291	Average Score Policy: -1979.15
# Episode 292	Average Score: 27.43
# Episode 292	Average Score Q: 3.25
# Episode 292	Average Score Policy: -1996.37
# Episode 293	Average Score: 27.64
# Episode 293	Average Score Q: 3.25
# Episode 293	Average Score Policy: -2013.61
# Episode 294	Average Score: 27.71
# Episode 294	Average Score Q: 3.26
# Episode 294	Average Score Policy: -2030.89
# Episode 295	Average Score: 27.71
# Episode 295	Average Score Q: 3.26
# Episode 295	Average Score Policy: -2048.18
# Episode 296	Average Score: 27.71
# Episode 296	Average Score Q: 3.26
# Episode 296	Average Score Policy: -2065.54
# Episode 297	Average Score: 27.95
# Episode 297	Average Score Q: 3.26
# Episode 297	Average Score Policy: -2082.96
# Episode 298	Average Score: 27.94
# Episode 298	Average Score Q: 3.26
# Episode 298	Average Score Policy: -2100.43
# Episode 299	Average Score: 27.77
# Episode 299	Average Score Q: 3.26
# Episode 299	Average Score Policy: -2117.88
# Episode 300	Average Score: 27.79
# Episode 300	Average Score Q: 3.26
# Episode 300	Average Score Policy: -2135.27
# Episode 300	Average Score: 27.79
# Episode 301	Average Score: 28.05
# Episode 301	Average Score Q: 3.26
# Episode 301	Average Score Policy: -2152.68
# Episode 302	Average Score: 28.08
# Episode 302	Average Score Q: 3.27
# Episode 302	Average Score Policy: -2170.11
# Episode 303	Average Score: 28.18
# Episode 303	Average Score Q: 3.27
# Episode 303	Average Score Policy: -2187.52
# Episode 304	Average Score: 28.10
# Episode 304	Average Score Q: 3.27
# Episode 304	Average Score Policy: -2204.93
# Episode 305	Average Score: 28.17
# Episode 305	Average Score Q: 3.26
# Episode 305	Average Score Policy: -2222.34
# Episode 306	Average Score: 28.22
# Episode 306	Average Score Q: 3.26
# Episode 306	Average Score Policy: -2239.72
# Episode 307	Average Score: 28.13
# Episode 307	Average Score Q: 3.26
# Episode 307	Average Score Policy: -2257.08
# Episode 308	Average Score: 28.21
# Episode 308	Average Score Q: 3.26
# Episode 308	Average Score Policy: -2274.43
# Episode 309	Average Score: 28.21
# Episode 309	Average Score Q: 3.25
# Episode 309	Average Score Policy: -2291.75
# Episode 310	Average Score: 28.46
# Episode 310	Average Score Q: 3.25
# Episode 310	Average Score Policy: -2309.04
# Episode 311	Average Score: 28.45
# Episode 311	Average Score Q: 3.25
# Episode 311	Average Score Policy: -2326.33
# Episode 312	Average Score: 28.75
# Episode 312	Average Score Q: 3.24
# Episode 312	Average Score Policy: -2343.61
# Episode 313	Average Score: 28.99
# Episode 313	Average Score Q: 3.24
# Episode 313	Average Score Policy: -2360.88
# Episode 314	Average Score: 29.00
# Episode 314	Average Score Q: 3.24
# Episode 314	Average Score Policy: -2378.16
# Episode 315	Average Score: 28.94
# Episode 315	Average Score Q: 3.23
# Episode 315	Average Score Policy: -2395.41
# Episode 316	Average Score: 28.66
# Episode 316	Average Score Q: 3.23
# Episode 316	Average Score Policy: -2412.58
# Episode 317	Average Score: 28.80
# Episode 317	Average Score Q: 3.22
# Episode 317	Average Score Policy: -2429.65
# Episode 318	Average Score: 28.73
# Episode 318	Average Score Q: 3.22
# Episode 318	Average Score Policy: -2446.74
# Episode 319	Average Score: 28.72
# Episode 319	Average Score Q: 3.21
# Episode 319	Average Score Policy: -2463.77
# Episode 320	Average Score: 28.91
# Episode 320	Average Score Q: 3.20
# Episode 320	Average Score Policy: -2480.77
# Episode 321	Average Score: 29.07
# Episode 321	Average Score Q: 3.20
# Episode 321	Average Score Policy: -2497.74
# Episode 322	Average Score: 29.05
# Episode 322	Average Score Q: 3.19
# Episode 322	Average Score Policy: -2514.66
# Episode 323	Average Score: 29.35
# Episode 323	Average Score Q: 3.18
# Episode 323	Average Score Policy: -2531.57
# Episode 324	Average Score: 29.48
# Episode 324	Average Score Q: 3.18
# Episode 324	Average Score Policy: -2548.46
# Episode 325	Average Score: 29.38
# Episode 325	Average Score Q: 3.17
# Episode 325	Average Score Policy: -2565.31
# Episode 326	Average Score: 29.50
# Episode 326	Average Score Q: 3.17
# Episode 326	Average Score Policy: -2582.05
# Episode 327	Average Score: 29.80
# Episode 327	Average Score Q: 3.16
# Episode 327	Average Score Policy: -2598.77
# Episode 328	Average Score: 29.58
# Episode 328	Average Score Q: 3.15
# Episode 328	Average Score Policy: -2615.44
# Episode 329	Average Score: 29.55
# Episode 329	Average Score Q: 3.14
# Episode 329	Average Score Policy: -2632.01
# Episode 330	Average Score: 29.60
# Episode 330	Average Score Q: 3.14
# Episode 330	Average Score Policy: -2648.53
# Episode 331	Average Score: 29.49
# Episode 331	Average Score Q: 3.13
# Episode 331	Average Score Policy: -2664.97
# Episode 332	Average Score: 29.38
# Episode 332	Average Score Q: 3.13
# Episode 332	Average Score Policy: -2681.27
# Episode 333	Average Score: 29.48
# Episode 333	Average Score Q: 3.12
# Episode 333	Average Score Policy: -2697.48
# Episode 334	Average Score: 29.55
# Episode 334	Average Score Q: 3.12
# Episode 334	Average Score Policy: -2713.58
# Episode 335	Average Score: 29.51
# Episode 335	Average Score Q: 3.11
# Episode 335	Average Score Policy: -2729.59
# Episode 336	Average Score: 29.21
# Episode 336	Average Score Q: 3.10
# Episode 336	Average Score Policy: -2745.47
# Episode 337	Average Score: 29.39
# Episode 337	Average Score Q: 3.10
# Episode 337	Average Score Policy: -2761.26
# Episode 338	Average Score: 29.42
# Episode 338	Average Score Q: 3.09
# Episode 338	Average Score Policy: -2776.94
# Episode 339	Average Score: 29.22
# Episode 339	Average Score Q: 3.09
# Episode 339	Average Score Policy: -2792.52
# Episode 340	Average Score: 29.21
# Episode 340	Average Score Q: 3.08
# Episode 340	Average Score Policy: -2807.97
# Episode 341	Average Score: 29.12
# Episode 341	Average Score Q: 3.08
# Episode 341	Average Score Policy: -2823.32
# Episode 342	Average Score: 28.90
# Episode 342	Average Score Q: 3.07
# Episode 342	Average Score Policy: -2838.57
# Episode 343	Average Score: 29.02
# Episode 343	Average Score Q: 3.07
# Episode 343	Average Score Policy: -2853.69
# Episode 344	Average Score: 29.12
# Episode 344	Average Score Q: 3.06
# Episode 344	Average Score Policy: -2868.73
# Episode 345	Average Score: 29.21
# Episode 345	Average Score Q: 3.06
# Episode 345	Average Score Policy: -2883.73
# Episode 346	Average Score: 29.34
# Episode 346	Average Score Q: 3.05
# Episode 346	Average Score Policy: -2898.61
# Episode 347	Average Score: 29.26
# Episode 347	Average Score Q: 3.05
# Episode 347	Average Score Policy: -2913.43
# Episode 348	Average Score: 29.25
# Episode 348	Average Score Q: 3.04
# Episode 348	Average Score Policy: -2928.10
# Episode 349	Average Score: 29.30
# Episode 349	Average Score Q: 3.04
# Episode 349	Average Score Policy: -2942.76
# Episode 350	Average Score: 29.32
# Episode 350	Average Score Q: 3.03
# Episode 350	Average Score Policy: -2957.31
# Episode 351	Average Score: 29.31
# Episode 351	Average Score Q: 3.02
# Episode 351	Average Score Policy: -2971.75
# Episode 352	Average Score: 29.42
# Episode 352	Average Score Q: 3.02
# Episode 352	Average Score Policy: -2986.13
# Episode 353	Average Score: 29.67
# Episode 353	Average Score Q: 3.01
# Episode 353	Average Score Policy: -3000.43
# Episode 354	Average Score: 29.70
# Episode 354	Average Score Q: 3.01
# Episode 354	Average Score Policy: -3014.66
# Episode 355	Average Score: 29.43
# Episode 355	Average Score Q: 3.00
# Episode 355	Average Score Policy: -3028.80
# Episode 356	Average Score: 29.42
# Episode 356	Average Score Q: 3.00
# Episode 356	Average Score Policy: -3042.77
# Episode 357	Average Score: 29.48
# Episode 357	Average Score Q: 2.99
# Episode 357	Average Score Policy: -3056.61
# Episode 358	Average Score: 29.51
# Episode 358	Average Score Q: 2.99
# Episode 358	Average Score Policy: -3070.36
# Episode 359	Average Score: 29.60
# Episode 359	Average Score Q: 2.98
# Episode 359	Average Score Policy: -3083.97
# Episode 360	Average Score: 29.67
# Episode 360	Average Score Q: 2.98
# Episode 360	Average Score Policy: -3097.47
# Episode 361	Average Score: 29.56
# Episode 361	Average Score Q: 2.97
# Episode 361	Average Score Policy: -3110.90
# Episode 362	Average Score: 29.57
# Episode 362	Average Score Q: 2.96
# Episode 362	Average Score Policy: -3124.21
# Episode 363	Average Score: 29.78
# Episode 363	Average Score Q: 2.96
# Episode 363	Average Score Policy: -3137.43
# Episode 364	Average Score: 29.72
# Episode 364	Average Score Q: 2.95
# Episode 364	Average Score Policy: -3150.59
# Episode 365	Average Score: 29.82
# Episode 365	Average Score Q: 2.95
# Episode 365	Average Score Policy: -3163.65
# Episode 366	Average Score: 29.68
# Episode 366	Average Score Q: 2.94
# Episode 366	Average Score Policy: -3176.57
# Episode 367	Average Score: 29.69
# Episode 367	Average Score Q: 2.94
# Episode 367	Average Score Policy: -3189.37
# Episode 368	Average Score: 29.61
# Episode 368	Average Score Q: 2.93
# Episode 368	Average Score Policy: -3202.02
# Episode 369	Average Score: 29.61
# Episode 369	Average Score Q: 2.93
# Episode 369	Average Score Policy: -3214.54
# Episode 370	Average Score: 29.60
# Episode 370	Average Score Q: 2.92
# Episode 370	Average Score Policy: -3226.94
# Episode 371	Average Score: 29.67
# Episode 371	Average Score Q: 2.91
# Episode 371	Average Score Policy: -3239.25
# Episode 372	Average Score: 29.62
# Episode 372	Average Score Q: 2.91
# Episode 372	Average Score Policy: -3251.40
# Episode 373	Average Score: 29.86
# Episode 373	Average Score Q: 2.90
# Episode 373	Average Score Policy: -3263.45
# Episode 374	Average Score: 29.82
# Episode 374	Average Score Q: 2.89
# Episode 374	Average Score Policy: -3275.39
# Episode 375	Average Score: 29.93
# Episode 375	Average Score Q: 2.89
# Episode 375	Average Score Policy: -3287.23
# Episode 376	Average Score: 30.19
# Episode 376	Average Score Q: 2.88
# Episode 376	Average Score Policy: -3298.97
#
# Environment solved in 276 episodes!	Average Score: 30.19
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:193: UserWarning: Couldn't retrieve source code for container of type Actor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
